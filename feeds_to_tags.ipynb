# %%
# A script to input and combine data for models
import pandas as pd
import tensorflow as tf
from pandas import DataFrame
import numpy as np
import math
import heapq
from tqdm import tqdm
import random
import ast
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
#!pip install --upgrade tensorflow
#!pip install --upgrade pandas
#!pip install --upgrade numpy
#tf.debugging.set_log_device_placement(True)

# %%
df = pd.read_csv('users-feeds.csv')
df = shrink_users_df(df, 'user')
df.loc[:, 'is_following_feed'] = 1

df = add_negative_samples(df,'feed_id','user','is_following_feed')

classes = pd.read_csv('feed_classifer_counts.csv')
print(classes.head())
print(list(classes['feed_classifier_counts'])[2])
classes['feed_classifier_counts'] = classes['feed_classifier_counts'].apply(lambda x: ast.literal_eval(x))

classes['feed_classifier_counts'] = classes['feed_classifier_counts'].apply(lambda x: gets_tags(x))

# %%
df.head()

# %%
classes.head()

# %%
classes = classes[classes['feed_classifier_counts'].map(lambda x: x != [])]
classes.head()

# %%
def match_feeds(classifier_df, users_df):
    """
    Takes a 2 dataframes, first one with `feed` & `feed_classifier_counts` columns
    Second other one with `feed_id` column
    
    Adds `feed_classifier` as a column to second df
    """
    
    # Merge dataframes    
    joined_df = users_df.merge(classifier_df[['feed_classifier_counts', 'feed']], how = 'left',
                    left_on = 'feed_id', right_on = 'feed').drop(columns= ['feed'])
    
    
    return joined_df

df_new = match_feeds(classes,df)
print(df_new.sample(20))

# %%
#reduce dups
def cleanse_double_tags(x):
    final_list = []
    for string in x:
        if string[0] == '"' and string[-1] == '"':
            final_list.append(string[1:-1])
        elif string[0] == "'" and string[-1] == "'":
            final_list.append(string[1:-1])
        else:
            final_list.append(string)
    return final_list

# %%
#reduce dups
def cleanse_hashtags(x):
    final_list = []
    for string in x:
        if string[0] == '#' and string[-1] != '#':
            final_list.append(string[1:])
        else: 
            final_list.append(string)
    return final_list

# %%
#df_new.loc[df_new.isnull()] = df_new.loc[df_new.isnull()].apply(lambda x: [])
df_new['feed_classifier_counts'] = df_new['feed_classifier_counts'].apply(lambda x: x if isinstance(x, list) else [])
df_new['feed_classifier_counts'] = df_new['feed_classifier_counts'].apply(lambda x: cleanse_double_tags(x))
df_new['feed_classifier_counts'] = df_new['feed_classifier_counts'].apply(lambda x: cleanse_hashtags(x))
df_new.sample(30)
# Out:
#            user  feed_id  is_following_feed  \
# 3440589    4320   428371                  0
# 6615474  208581   392071                  0
# 4799005   61931  1125293                  1
# 3548720  167211     6206                  1
# 5281491   79523  1848670                  0
# 6875192  545110  4442404                  0
# 1407914  187770  4676380                  0
# 3246024     669  3997446                  0
# 4346237   59273  3334971                  0
# 6000666  106209  5795266                  0
# 5094029  210571   442021                  0
# 189457    10089  1614536                  0
# 5716052  187514  2228280                  0
# 168741   177099  1882639                  0
# 1688806   26084  3679668                  0
# 4249701  115128   528880                  0
# 502838    99410   785479                  0
# 3153268  132211   453915                  0
# 2280235  567339   253184                  1
# 1514806  201178  6801792                  0
# 4466679  164958  4850185                  0
# 4543195   62928  2788844                  1
# 2079938  302364  7024788                  0
# 690145    94714   883488                  1
# 6544080     424  1528129                  1
# 5526421    4731  1473807                  0
# 3920010   99490  5830321                  1
# 3825448  183982   672976                  0
# 6262030  268818  1017615                  1
# 6739287  509441  2174846                  0
#
#                                     feed_classifier_counts
# 3440589                                                 []
# 6615474                                                 []
# 4799005                                                 []
# 3548720                                                 []
# 5281491                                                 []
# 6875192                                                 []
# 1407914                                                 []
# 3246024                                                 []
# 4346237                                                 []
# 6000666                                                 []
# 5094029                                                 []
# 189457                                                  []
# 5716052                                                 []
# 168741                                                  []
# 1688806                                                 []
# 4249701                                                 []
# 502838                                                  []
# 3153268                                                 []
# 2280235                                                 []
# 1514806                                                 []
# 4466679                                                 []
# 4543195                                                 []
# 2079938                                                 []
# 690145                                                  []
# 6544080  [google, cloud computing, apple, android, amaz...
# 5526421                                                 []
# 3920010                                                 []
# 3825448                                                 []
# 6262030  [food & war, interviews, publishing food, unca...
# 6739287                                                 []

# %%
def gets_tags(x):
  tags = x.get('tag')
  final_list = []
  if tags == None:
    return []
  for item in tags:
    final_list.append(item.get('tag'))
  return final_list


def try_conversion(x):
    try:
        return ast.literal_eval(x)
    except Exception as e:
        return {}
def shrink_users_df(df,user_id):
    userIds = np.random.choice(df[user_id].unique(),
                                    size=int(len(df[user_id].unique())*0.10),
                                    replace=False)
    return df.loc[df[user_id].isin(userIds)]
def add_negative_samples(df, item_tag, user_tag,label_tag):

    updated_df = pd.DataFrame(columns=[user_tag,item_tag,label_tag])
    all_feeds = df[item_tag].unique()
    users, items, labels = [], [], []

    user_item_set = set(zip(df[user_tag], df[item_tag]))
    num_negatives = 4

    for (u, i) in user_item_set:
        users.append(u)
        items.append(i)
        labels.append(1) # items that the user has interacted with are positive
        for _ in range(num_negatives):
            # randomly select an item
            negative_item = np.random.choice(all_feeds)
            # check that the user has not interacted with this item
            while (u, negative_item) in user_item_set:
                negative_item = np.random.choice(all_feeds)
            users.append(u)
            items.append(negative_item)
            labels.append(0) # items not interacted with are negative
    updated_df[user_tag] = users
    updated_df[item_tag] = items
    updated_df[label_tag] = labels
    del df
    return updated_df

def mask_first(x):
    """
    Return a list of 0 for the first item and 1 for all others
    """
    result = np.ones_like(x)
    result[0] = 0

    return result

# needs to add validate in the future
def train_test_split(full_df):
    df_test = df.copy(deep=True)
    df_test = df_test.groupby(['user']).first()

    df_test['user'] = df_test.index
    df_test = df_test[['user', 'feed_id','is_following_feed']]
    df_test = df_test.rename_axis(None, axis=1)

    df_train = df.copy(deep=True)
    mask = df.groupby(['user'])['user'].transform(mask_first).astype(bool)

    df_train = df.loc[mask]
    return df_train, df_test

# %%
from sklearn.preprocessing import MultiLabelBinarizer
mlb = MultiLabelBinarizer()

# %%
encode = mlb.fit(df_new['feed_classifier_counts'].tolist())
# Out:
# MultiLabelBinarizer()

# %%
len(list(encode.classes_))
# Out:
# 126605

# %%
list(encode.classes_)[6:]
# Out:
# ['" again?',
#  '">community<',
#  '"creative" editing',
#  '"final fantasy vii remake" (video game)',
#  '"hardcore" gaming',
#  '"helpful" toddlers',
#  '"the less they know',
#  '"új" iráni vadászgép',
#  '#',
#  '$$',
#  '$1 and free',
#  '$10 and beyond',
#  '$100 startup',
#  '$100-$250',
#  '$149',
#  '$199',
#  '$25-$50',
#  '$4.99',
#  '$5 and under',
#  '$99 xbox 360 kinect bundle',
#  '$apple watch series 2',
#  '$cl_f',
#  '$dia',
#  '$dx_f',
#  '$eem',
#  '$fxe',
#  '$gc_f',
#  '$gld',
#  '$indu',
#  '$iwm',
#  '$mtum',
#  '$ng_f',
#  '$qqq',
#  '$si_f',
#  '$slv',
#  '$spx',
#  '$spy',
#  '$uicideboy$',
#  '$uicideboy$ and germ',
#  '$uicideboys',
#  '$uup',
#  '$vlue',
#  '$xle',
#  '$z.99',
#  '& cemeteries',
#  '& eco',
#  '& food',
#  '& health',
#  '& paper',
#  '& productivity',
#  '& storage',
#  '&apos;n sync',
#  "'77",
#  "'80's",
#  "'90s",
#  "'90s fashion",
#  "'90s nostalgia",
#  "'cool websites and tools' series",
#  "'n sync",
#  "'ndrangheta",
#  "'ndrangheta al nord",
#  "'nude' airport body scanners",
#  "'ship shape",
#  "'tocks",
#  "'tocktober 2014",
#  "'tocktober 2015",
#  "'vampire diaries' finale week",
#  '(((s)))',
#  '(druid) shifting perspectives',
#  '(globule et télescope)²',
#  '(hed) p.e.',
#  '(hunter) scattered shots',
#  '(mage) arcane brilliance',
#  '(microsoft press)',
#  '(null)',
#  '(paladin) the light and how to swing it',
#  '(priest) spiritual guidance',
#  '(product)red',
#  '(rogue) encrypted text',
#  '(sandy) alex g',
#  '(shaman) totem talk',
#  '(urgent) gunmen kill 10 foreign tourists in northern pakistan -police',
#  '(w)archives',
#  '(warlock) blood pact',
#  '(warrior) the care and feeding of warriors',
#  '(x)html',
#  '* |ω・）',
#  '*ar',
#  '*glowna',
#  '*nix',
#  '*nsync',
#  '*ptr',
#  '*身体と意識bc',
#  '+18',
#  '+32',
#  '+classical',
#  '+jazz',
#  '+metal',
#  '---',
#  '-homepage-suppress',
#  '-midterms-2018',
#  '-product review',
#  '-recirc-suppress',
#  '-suppress',
#  '.......',
#  '...and f*ck you too',
#  '...and you will know us by the trail of dead',
#  '.domains',
#  '.geek - : it pro',
#  '.gov',
#  '.hack',
#  '.htaccess',
#  '.mac',
#  '.net',
#  '.net & windows programming',
#  '.net & windows programming (msp)',
#  '.net 3.5',
#  '.net 4.0',
#  '.net 4.5',
#  '.net api',
#  '.net applications development',
#  '.net architecture',
#  '.net core',
#  '.net framework',
#  '.net3.5',
#  '.net4',
#  '.net4.5',
#  '.next',
#  '.plan - .actie',
#  '.plan - development',
#  '.plan - serverbeheer',
#  '0 day',
#  '0 days',
#  '0% android',
#  '0% apple',
#  '0-day',
#  '0.5',
#  '000 maniacs',
#  '000: armageddon',
#  '000: kill team',
#  '001',
#  '002',
#  '003',
#  '004',
#  '007',
#  '01 - birthday pursuit',
#  '01 - glower vacuum',
#  "01 - to those who'd ground me",
#  '010',
#  '011',
#  '012',
#  '013',
#  '014',
#  '015',
#  '016',
#  '017',
#  '018',
#  '019',
#  '02 - choosing my religion',
#  '02 - that perfect girl',
#  "02 - three's a crowd",
#  '021',
#  '023',
#  '026',
#  "03 - the butterflies won't fly away",
#  '03 greedo',
#  '030',
#  '031',
#  '032',
#  '034',
#  '035',
#  '036',
#  '037',
#  '038',
#  '04 - it all returns',
#  "04 - just hangin' out with my family",
#  "04 - the 'do' list",
#  '04 - vote for robin',
#  '04 – of mike and men',
#  '05-12yrs (kid)',
#  '062',
#  '064daebf-345c-526e-9981-33e07dd36256',
#  '080',
#  '0ad',
#  '0day',
#  '0day trackers',
#  '0ls',
#  '0patch',
#  '0xword',
#  '0zapftis',
#  '1',
#  '1 billion',
#  '1 courts wikileaks substitute',
#  '1 legal assange substitute',
#  '1 mile north',
#  '1 million dollars',
#  '1 percent',
#  '1 pinocchio',
#  '1 year ago',
#  '1&1',
#  '1-3 years',
#  '1-o',
#  '1. bundesliga',
#  '1. fc kaiserslautern',
#  '1. fc köln',
#  '1. fc nürnberg',
#  '1. fsv mainz 05',
#  '1.0',
#  '1.1.1.1',
#  '1.1.10',
#  '1.4',
#  '1.5',
#  '1.7',
#  '1.8',
#  '10 anni de ilfattoquotidiano.it',
#  '10 ans jdg',
#  '10 best songs',
#  '10 books making news',
#  '10 cents',
#  '10 cloverfield lane',
#  '10 crowns',
#  '10 ft. ganja plant',
#  '10 ingredients or less',
#  '10 kids 2 dads',
#  '10 second songs',
#  '10 stories you may have missed',
#  '10 string symphony',
#  '10 things before opening bell',
#  '10 things in tech',
#  '10 things in tech sai',
#  '10 things in tech sai uk',
#  '10 tricks',
#  '10 um 10',
#  '10 weekly goals',
#  '10 years',
#  '10.04',
#  '10.10',
#  '10.10.2',
#  '10.12',
#  '10.6 snow leopard',
#  '10.7',
#  '10.7 lion',
#  '10.9',
#  '100',
#  '100 years of new york music',
#  '100% renewable electricity',
#  '100% renewable energy',
#  '100% renewable power',
#  '1000 gram',
#  '1000 words',
#  '10000 steps',
#  '1000memories',
#  '1000mods',
#  '100blumen',
#  '100ft robot golf',
#  '100s',
#  '101',
#  '101 helium',
#  '101 rent boys',
#  '101: the airborne invasion of normandy',
#  '101s',
#  '101usosdeevernote',
#  '102',
#  '1080p',
#  '1099',
#  '10b5-1',
#  '10cc',
#  '10deep',
#  '10k steps',
#  '10nm',
#  '10s',
#  '10th anniversary',
#  '10th annual crunchies',
#  '10th annual crunchies award show',
#  '10th annual crunchies awards',
#  '10th ave s',
#  '10th gen',
#  '11',
#  '11 22 63',
#  '11 5th anniversary',
#  '11 acorn lane',
#  '11 bit studios',
#  '11 coisas que não se deve fazer no primeiro encontro',
#  '11 minutes',
#  '11 stories',
#  '11-foot-8',
#  '11.04',
#  '11.10',
#  '112',
#  '11a',
#  '11s',
#  '11th year anniversary',
#  '12 bests',
#  '12 days - opfp',
#  '12 days of christmas',
#  '12 days of christmas 2017',
#  '12 days of deals',
#  '12 days of gifts',
#  '12 hours of sebring',
#  '12 małp',
#  '12 million',
#  '12 monkeys',
#  '12 stone toddler',
#  '12 stones',
#  '12 volt',
#  '12-inch macbook',
#  '12-inch macbook air',
#  '12-step',
#  '12.04',
#  '120 yard',
#  '1200 micrograms',
#  '1200 techniques',
#  '1201',
#  '121',
#  '12333',
#  '123d',
#  '125',
#  '1260',
#  '12am',
#  '12b69907-cfa6-4eff-bcfa-7c0642a589e6',
#  '12daysofchristmas',
#  '12th man',
#  '12th planet',
#  '12th planet & protohype',
#  '13',
#  '13 finálék',
#  '13 reasons why',
#  '13 sentinels: aegis rim',
#  '13-18yrs (teen)',
#  '13-inch',
#  '13-inch macbook pro',
#  '131',
#  '138 games',
#  '13be3af1-81fe-4e40-b9b5-ca2f935c206f',
#  '13f',
#  '13inchmacbookpro',
#  '13inchmbp',
#  '13th floor elevators',
#  '14 iced bears',
#  '14 nanometer',
#  '140',
#  '140 proof',
#  '1414-app',
#  '1443',
#  '144hz monitor',
#  '14kt',
#  '14nm',
#  '14th annual techcrunch summer party',
#  '14th st corridor',
#  '14th street',
#  '14th street nw',
#  '15 fragen',
#  '15 minutes of fame',
#  '15 off',
#  '15-inch',
#  '151',
#  '153',
#  '154',
#  '15m',
#  '16 bit lolitas',
#  '16 bits',
#  '16 horsepower',
#  '16 segment',
#  '16-bit',
#  '16-core',
#  '16-inch macbook pro',
#  '16.04 lts',
#  '1605',
#  '1619',
#  '1619project',
#  '162',
#  '162173 ryugu',
#  '165',
#  '16gb',
#  '17 - 22 monitor',
#  '174',
#  '17586063',
#  '17thcentury',
#  '18',
#  '18 carat affair',
#  '18+',
#  '1802',
#  '1805',
#  '180s',
#  '186',
#  '18650',
#  '187',
#  '1886',
#  '18f2553',
#  '18yearsold',
#  '19',
#  '19 kids and counting',
#  '19 kids and counting ratings',
#  '1900mhz hspa+',
#  "1910's",
#  '1910s',
#  '1911',
#  '1916',
#  "1920's",
#  '1920s',
#  '1920s mugshots',
#  "1930's",
#  '1930s',
#  '1931: scheherazade',
#  '1935',
#  '1935 alfa romeo tipo c 8c-35',
#  "1940's",
#  '1940s',
#  '1942: the pacific air war',
#  '195',
#  "1950's",
#  '1950s',
#  '1955',
#  '1956-os ünnepség',
#  '1960s',
#  '1962',
#  '1964',
#  '1965',
#  '1966 ford gt40',
#  '1967 ford mustang',
#  '1969',
#  "1970's",
#  '1970s',
#  '1976',
#  '1976 ferrari 312 t2',
#  '1979 revolution: black friday',
#  '1980s',
#  '1982',
#  '1984',
#  '1984 is not a manual for statecraft',
#  '1985 air india bombing',
#  '1986 hawaii',
#  '1987 buick gnx',
#  '1988 seoul olympics',
#  '1990s',
#  '1991',
#  '1992',
#  '19a0',
#  '19a0s',
#  '19th century',
#  '19th century religion',
#  '1a3fe567-cf02-44a9-92dc-bb7a103c50ee',
#  '1c',
#  '1c 8.2',
#  '1c интеграция',
#  '1c-bitrix',
#  '1c: ino-co',
#  '1d',
#  '1d after dark',
#  '1d1e2c69-c3b3-4edb-99e3-c210ff382f28',
#  '1dc',
#  '1dxii',
#  '1dxmarkii',
#  '1live',
#  '1live dj session',
#  '1ls',
#  '1password',
#  '1password 4',
#  '1password app extension',
#  '1password beta',
#  '1password extension',
#  '1password families',
#  '1password for android',
#  '1password for ios',
#  '1password for ipad',
#  '1password for mac',
#  '1password for teams',
#  '1password for windows',
#  '1password integration',
#  '1password ios integration',
#  '1password pro',
#  '1password show',
#  '1password teams',
#  '1password touch',
#  '1password x',
#  '1reasontobe',
#  '1reasonwhy',
#  '1series',
#  '1st amendment',
#  '1year',
#  '1с',
#  '1с 7.7',
#  '1с предприятие 8',
#  '1с сервер',
#  '1с-битрикс',
#  '1с-битрикс обучение',
#  '1с:предприятие',
#  '1€',
#  '2 billion beats',
#  '2 broke girls',
#  '2 broke girls cancelled or renewed?',
#  '2 brothers on the 4th floor',
#  '2 chainz',
#  '2 dope queens',
#  '2 fabiola',
#  '2 live crew',
#  '2 minute lessons',
#  '2 pinocchios',
#  '2 pistols',
#  '2 point recipes',
#  '2 raptors and 100 bullets',
#  '2 unlimited',
#  '2-factor authentication',
#  '2-in-1',
#  '2. bundesliga',
#  '2. liga',
#  '2.0',
#  '2.4ghz antenna',
#  '2.5',
#  '2.8l ii',
#  '2.8l iii',
#  '20',
#  '20 kids and counting',
#  '20 macs for 2020',
#  '20 people to follow on twitter',
#  '20 ratings',
#  '20 something',
#  '20 somethings',
#  '20 years later',
#  '20% time',
#  '20-somethings',
#  '20-years-of-harry-potter',
#  '2000 and one',
#  '2000s',
#  '2001',
#  '2001 a space odyssey',
#  '2005 lamborghini concept s',
#  '2007#video',
#  '2007scape',
#  '2008 nba finals',
#  '2008 r2',
#  '2009 fomc transcripts',
#  '2010',
#  '2010 canada digital year in review',
#  '2010 elections',
#  '2010 holiday gift guide',
#  '2010 in review',
#  '2010 lego sets',
#  '2010 midterm elections',
#  '2010 u.s. digital year in review',
#  '2010-nba-finals',
#  '2011',
#  '2011 election',
#  '2011 lego sets',
#  '2012',
#  '2012 and mayan calendar',
#  '2012 campaign',
#  '2012 chevrolet camaro zl1',
#  '2012 election',
#  '2012 elections',
#  '2012 hyundai azera',
#  '2012 hyundai grandeur',
#  '2012 nba draft',
#  '2012 nissan juke',
#  '2012 porsche 911 gt2 rs',
#  '2012 porsche cayenne turbo',
#  '2012 predictions',
#  '2012 presidential',
#  '2012 presidential campaign',
#  '2012 presidential election',
#  '2012 presidential elections',
#  '2012 queensland election',
#  '2012 summer olympics',
#  '2012 super bowl',
#  '2012 trends',
#  '2012 wimbledon',
#  '2012 year in review',
#  '2013',
#  '2013 amateur draft',
#  '2013 bmw m5',
#  '2013 campaign',
#  '2013 elections',
#  '2013 f1 race data',
#  '2013 f1 season',
#  '2013 ferrari f12 berlinetta',
#  '2013 gift guide',
#  '2013 honda civic',
#  '2013 legislature',
#  '2013 mac pro',
#  '2013 mercedes-benz clc',
#  '2013 mercedes-benz sls amg gt',
#  '2013 moab easter jeep safari',
#  '2013 nba all-star game',
#  '2013 nba all-star snubs',
#  '2013 new york auto show',
#  '2013 nexus 7',
#  '2013 nissan pathfinder',
#  '2013 positional power rankings',
#  '2013 recruiting profiles',
#  '2013 shanghai motor show',
#  '2013 subaru wrx concept',
#  '2013 voter guide',
#  '2013 world series',
#  '2013 year in review',
#  '2013-q3 promotions',
#  '2013-q4 promotions',
#  '2014',
#  '2014 aston martin rapide s',
#  '2014 bet awards',
#  '2014 british gp',
#  '2014 cadillac cts',
#  '2014 campaign',
#  '2014 corvette',
#  '2014 election',
#  '2014 emmy awards',
#  '2014 emmys',
#  '2014 f1',
#  '2014 f1 season',
#  '2014 fantasy baseball rankings',
#  '2014 ferrari f12 berlinetta',
#  '2014 ferrari laferrari',
#  '2014 fiba world cup',
#  '2014 fifa world cup',
#  '2014 freightliner sprinter',
#  '2014 german gp',
#  '2014 gp2 season',
#  '2014 hyundai i40 tourer',
#  '2014 in review with io9',
#  '2014 indiana',
#  '2014 kia sportage',
#  '2014 land rover lr4',
#  '2014 land rover range rover',
#  '2014 land rover range rover sport',
#  '2014 mazda miata',
#  '2014 mercedes-benz sprinter',
#  '2014 midterms',
#  '2014 mlb playoffs',
#  '2014 mtv vmas',
#  '2014 nba playoffs',
#  '2014 nba preview',
#  '2014 ncaa tournament',
#  '2014 nfl mock draft',
#  '2014 nfl playoffs',
#  '2014 nfl preview',
#  '2014 notre dame',
#  '2014 olympics',
#  '2014 oscars',
#  '2014 paris motor show',
#  '2014 power issue',
#  '2014 recruiting',
#  '2014 scion tc',
#  '2014 senate elections',
#  '2014 sochi winter olympics',
#  '2014 subaru forester',
#  '2014 subaru outback',
#  '2014 trade value',
#  '2014 trends',
#  '2014 volvo v60',
#  '2014 volvo xc60',
#  '2014 vw golf gtd',
#  '2014 world cup',
#  '2014 world cup brazil',
#  '2014 world series',
#  '2014)',
#  '2014-q1 hotel promotions',
#  '2014-q2 hotel promotions',
#  '2014-q3 hotel promotions',
#  '2014-q4 hotel promotions',
#  '2014ces',
#  '2015',
#  '2015 academy awards',
#  '2015 acura nsx',
#  '2015 chevrolet ss',
#  '2015 chevy corvette',
#  '2015 dodge challenger srt hellcat',
#  '2015 emmys',
#  '2015 fantasy baseball overrated',
#  '2015 fantasy baseball rankings',
#  '2015 fantasy baseball sleeper',
#  '2015 ford f-150',
#  '2015 ford mustang',
#  '2015 ford mustang gt350',
#  '2015 ford shelby gt350',
#  '2015 gift guide',
#  '2015 gift guides',
#  '2015 grammy awards',
#  '2015 hackaday prize',
#  '2015 hyundai sonata',
#  '2015 in review',
#  '2015 jeep renegade trailhawk',
#  '2015 land rover range rover sport svr',
#  '2015 march madness',
#  "2015 men's ncaa tournament",
#  '2015 mlb draft',
#  '2015 mlb playoffs',
#  '2015 mlb spring training',
#  '2015 monster madness 9',
#  '2015 nba finals',
#  '2015 nba playoffs',
#  '2015 ncaa basketball tournament',
#  "2015 ncaa women's basketball tournament",
#  '2015 nfl draft',
#  '2015 nfl preview',
#  '2015 nhl playoffs',
#  '2015 ny auto show',
#  '2015 oscars',
#  '2015 sloan sports analytics conference',
#  '2015 srt barracuda',
#  '2015 subaru wrx',
#  '2015 subaru wrx sti',
#  '2015 toyota sienna',
#  '2015 u.k. election',
#  '2015 u.s. open',
#  '2015 upfronts',
#  '2015 vmas',
#  '2015 volkswagen golf r',
#  '2015 volkswagen gti',
#  "2015 women's ncaa tournament",
#  "2015 women's world cup",
#  '2015 world cup',
#  '2015 world series',
#  '2015 zips projections',
#  '2015-16 nba previews',
#  '2015-q1',
#  '2015-q2 hotel and travel deals',
#  '2015-q4 promotions and deals',
#  '2016',
#  '2016 academy awards',
#  '2016 aug courses',
#  '2016 bentley falcon',
#  '2016 camaro',
#  '2016 campaign',
#  '2016 candidates',
#  '2016 chevrolet camaro',
#  '2016 chevrolet colorado',
#  '2016 congressional elections',
#  '2016 democratic primary',
#  '2016 distilled',
#  '2016 election',
#  '2016 election coverage',
#  '2016 election meddling',
#  '2016 elections',
#  '2016 emmys',
#  '2016 euros',
#  '2016 fantasy baseball rankings',
#  '2016 fantasy baseball rookies',
#  '2016 ford mustang',
#  '2016 golf r',
#  '2016 gop primary',
#  '2016 hackaday prize',
#  '2016 honda cb500f',
#  '2016 hyundai elantra',
#  '2016 kickoff',
#  '2016 march madness',
#  '2016 mazda miata',
#  '2016 mazda mx-5 miata',
#  "2016 men's ncaa tournament",
#  '2016 mlb draft',
#  '2016 mlb playoffs',
#  '2016 mlb preview',
#  '2016 mlb season',
#  '2016 national elections',
#  '2016 nba all-star game',
#  '2016 nba playoffs',
#  '2016 ncaa basketball tournament',
#  '2016 ncaa tournament',
#  '2016 nfl draft',
#  '2016 nfl preview',
#  '2016 nissan titan xd',
#  '2016 olympic games',
#  '2016 olympics',
#  '2016 oscars',
#  '2016 presidential campaign',
#  '2016 presidential election',
#  '2016 presidential elections',
#  '2016 presidential race',
#  '2016 range rover sport svr',
#  '2016 recruiting profiles',
#  '2016 republican candidates',
#  '2016 republican primary',
#  '2016 rio olympics',
#  '2016 senate elections',
#  '2016 state and local elections',
#  '2016 summer olympics',
#  '2016 super bowl ad',
#  '2016 tony awards',
#  '2016 u.s. open',
#  '2016 u.s. presidential election',
#  '2016 us election',
#  '2016 us presidential election',
#  '2016 us presidential elections',
#  "2016 women's ncaa tournament",
#  '2016 year in review',
#  '2016-17 hockey',
#  '2016-election',
#  '2016-national-elections',
#  '2016election',
#  '2017',
#  '2017 academy awards',
#  '2017 carry-on electronics ban',
#  '2017 detroit auto show',
#  '2017 fantasy baseball overrated',
#  '2017 fantasy baseball points leagues',
#  '2017 fantasy baseball rookies',
#  '2017 fantasy baseball sleepers',
#  '2017 feb meetings',
#  '2017 geekwire summit',
#  '2017 golden globes',
#  '2017 hackaday prize',
#  '2017 hackaday superconference',
#  '2017 in review',
#  "2017 men's ncaa tournament",
#  '2017 mlb season preview',
#  '2017 nba mvp',
#  '2017 ops leagues',
#  '2017 oscars',
#  '2017 top-10 prospect update',
#  "2017 women's ncaa tournament",
#  '2017 world series',
#  '2017 zips projections',
#  '2017)',
#  '2017-mlb-preview',
#  '2017-nba-draft',
#  '2017-nba-finals',
#  '2017-nba-free-agency',
#  '2017-nba-playoffs',
#  '2017-ncaa-tournament',
#  '2017-nhl-playoffs',
#  '2018',
#  '2018 associate salary increase',
#  '2018 bracket',
#  '2018 campaign',
#  '2018 election',
#  '2018 elections',
#  '2018 fantasy baseball overrated',
#  '2018 fantasy baseball team previews',
#  '2018 fifa world cup',
#  '2018 governors elections',
#  '2018 hackaday superconference',
#  '2018 holiday gift guide',
#  '2018 house elections',
#  '2018 iphone event',
#  '2018 iphones',
#  '2018 lexus lc 500',
#  '2018 mid-term election',
#  '2018 midterm elections',
#  '2018 midterms',
#  '2018 mlb draft',
#  '2018 name of the year',
#  '2018 nba playoffs',
#  '2018 ncaa tournament',
#  '2018 nhl playoffs',
#  '2018 nissan gt-r',
#  '2018 nissan titan',
#  '2018 olympics',
#  '2018 oscars',
#  '2018 positional power rankings',
#  '2018 preview',
#  '2018 senate elections',
#  '2018 trade value',
#  '2018 tsunami',
#  '2018 winter olympics',
#  '2018 world cup',
#  '2018-19 nba season',
#  '2019 bbwaa ballot',
#  '2019 bet awards',
#  '2019 chevrolet corvette',
#  '2019 cricket world cup',
#  '2019 democratic debate',
#  '2019 end-of-year thoughts',
#  '2019 fantasy baseball buy',
#  '2019 fantasy baseball overrated',
#  '2019 fantasy baseball sleepers',
#  '2019 fantasy baseball team previews',
#  '2019 fantasy team previews',
#  '2019 hackaday prize',
#  '2019 honda passport',
#  '2019 in review',
#  '2019 indy 500',
#  '2019 iphones',
#  '2019 mlb trade deadline',
#  '2019 name of the year',
#  '2019 nba all-star game',
#  '2019 ncaa tournament',
#  "2019 ncaa women's tournament",
#  '2019 oscars',
#  '2019 replacement-level killers',
#  '2019 rugby world cup',
#  '2019 tony awards',
#  '2019 toyota camry',
#  '2019 toyota supra',
#  '2019 tribeca film festival',
#  "2019 women's ncaa tournament",
#  '2019 womens world cup',
#  '2019 zips projections',
#  '2020',
#  '2020 bbwaa ballot',
#  '2020 campaign',
#  '2020 census',
#  '2020 debates',
#  '2020 democratic debates',
#  '2020 democratic presidential primary',
#  '2020 democratic primary',
#  '2020 democratic primary debates',
#  '2020 democrats',
#  '2020 election',
#  '2020 elections',
#  '2020 hyundai sonata hybrid',
#  '2020 kickoff',
#  '2020 mlb playoffs',
#  '2020 mls playoffs',
#  '2020 nba bubble',
#  '2020 nba playoffs',
#  '2020 nfl draft',
#  '2020 nhl playoffs',
#  '2020 presidential election',
#  '2020 replacement-level killers',
#  '2020 republican primary',
#  '2020 senate elections',
#  '2020 stanley cup final',
#  '2020 us presidential election',
#  '2020 wnba finals',
#  '2020 womens us open',
#  '2020-presidential-election',
#  '2021 bbwaa ballot',
#  '2022 world cup',
#  '206',
#  '207',
#  '208 playstation awards',
#  '20conceptos',
#  '20ish questions',
#  '20syl',
#  '20th',
#  '20th century',
#  '20th century fox',
#  '20th century fox television',
#  '20th century fox tv',
#  '21 - 22 monitor',
#  '21 questions',
#  '21 savage',
#  '21 savage & xxxtentacion',
#  '21 savage (rapper)',
#  '214',
#  '2160p',
#  '21sextury',
#  '21st',
#  '21st century fox',
#  '21st century house music',
#  '21st century living',
#  '21st-century fox',
#  '220 volt',
#  '22nm',
#  '22tracks',
#  '23',
#  '23 meadow st',
#  '232',
#  '23andme',
#  '24',
#  '24  inch monitor',
#  '24 horas de le mans',
#  '24 hour product diaries',
#  "24 hours of 'tocks 2014",
#  '24 hours of daytona',
#  '24 hours of le mans',
#  '24 hours of lemons',
#  '24 hours of nurburgring',
#  '24 hours of nürburgring',
#  '24 live another day',
#  '24 ratings',
#  '24 recap',
#  '24+ inch monitor',
#  '24-core',
#  '240',
#  '240sx',
#  '242',
#  '24: legacy',
#  '24: live another day',
#  '24: live another day ratings',
#  '24hrs & slicklaflare',
#  '24lm',
#  '24me',
#  '250 million',
#  '250mx',
#  '251',
#  '2562',
#  '256aes',
#  '25b3659e-0aa5-4df7-8836-f4dba4007b5c',
#  '25s',
#  '25th amendment',
#  '25th anniversary',
#  '263ca764-8186-4183-addd-5fab0603f331',
#  '266',
#  '27 made up things you didnt know about me',
#  '27" imac',
#  '272',
#  '275 madison avenue',
#  '277',
#  '278',
#  '280',
#  '2814',
#  '287',
#  '29094b35-df2e-4965-a288-12f479123c4a',
#  '297',
#  '2:54',
#  '2am club',
#  '2ba0c2de-2a2e-44c3-9d24-40315beca5b9',
#  '2beat',
#  '2cellos',
#  '2ch',
#  '2d',
#  ...]

# %%
"'90s" in list(encode.classes_)
# Out:
# True

# %%
"90s" in list(encode.classes_)
# Out:
# True

# %%
list(encode.classes_).index("'90s")
# Out:
# 60

# %%
list(encode.classes_).index("90s")
# Out:
# 1607
